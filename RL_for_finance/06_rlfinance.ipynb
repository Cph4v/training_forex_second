# %% [markdown]
# <img src="https://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Reinforcement Learning for Finance
#
# **Chapter 06 &mdash; Algorithmic Trading**
#
# &copy; Dr. Yves J. Hilpisch
#
# <a href="https://tpq.io" target="_blank">https://tpq.io</a> | <a href="https://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:team@tpq.io">team@tpq.io</a>

# %% [markdown]
# ## Prediction Game Revisited

# %%
import math
import random
import numpy as np
import pandas as pd
from pylab import plt, mpl

# %%
plt.style.use('seaborn-v0_8')
mpl.rcParams['figure.dpi'] = 300
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.family'] = 'serif'
np.set_printoptions(suppress=True)

# %%
from finance import *

# %%
finance = Finance('GLD', 'r', min_accuracy=47.5,
              n_features=8)

# %%
finance.data[finance.symbol].plot(title=finance.symbol,
                                  lw=1.0, c='b');

# %%
from dqlagent import *

# %%
random.seed(100)
tf.random.set_seed(100)

# %%
dqlagent = DQLAgent(
                 finance.n_features, finance, lr=0.0001)

# %%
# %time dqlagent.learn(500)
# Out:
# episode=  14 | treward=  5.000 | max=  8.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/RL/RL_platform/RL_for_finance/dqlagent.py:97, in DQLAgent.learn(self, episodes)
#      95             break
#      96     if len(self.memory) > self.batch_size:
# ---> 97         self.replay()
#      98 print()
#
# File ~/RL/RL_platform/RL_for_finance/dqlagent.py:69, in DQLAgent.replay(self)
#      67         target = self.model.predict(state)
#      68         target[0, action] = reward
# ---> 69         self.model.fit(state, target, epochs=1, verbose=False)
#      70 if self.epsilon > self.epsilon_min:
#      71     self.epsilon *= self.epsilon_decay
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_v1.py:789, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     786 self._check_call_args('fit')
#     788 func = self._select_training_loop(x)
# --> 789 return func.fit(
#     790     self,
#     791     x=x,
#     792     y=y,
#     793     batch_size=batch_size,
#     794     epochs=epochs,
#     795     verbose=verbose,
#     796     callbacks=callbacks,
#     797     validation_split=validation_split,
#     798     validation_data=validation_data,
#     799     shuffle=shuffle,
#     800     class_weight=class_weight,
#     801     sample_weight=sample_weight,
#     802     initial_epoch=initial_epoch,
#     803     steps_per_epoch=steps_per_epoch,
#     804     validation_steps=validation_steps,
#     805     validation_freq=validation_freq,
#     806     max_queue_size=max_queue_size,
#     807     workers=workers,
#     808     use_multiprocessing=use_multiprocessing)
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_arrays_v1.py:647, in ArrayLikeTrainingLoop.fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     643     raise ValueError('`validation_steps` should not be specified if '
#     644                      '`validation_data` is None.')
#     645   val_x, val_y, val_sample_weights = None, None, None
# --> 647 return fit_loop(
#     648     model,
#     649     inputs=x,
#     650     targets=y,
#     651     sample_weights=sample_weights,
#     652     batch_size=batch_size,
#     653     epochs=epochs,
#     654     verbose=verbose,
#     655     callbacks=callbacks,
#     656     val_inputs=val_x,
#     657     val_targets=val_y,
#     658     val_sample_weights=val_sample_weights,
#     659     shuffle=shuffle,
#     660     initial_epoch=initial_epoch,
#     661     steps_per_epoch=steps_per_epoch,
#     662     validation_steps=validation_steps,
#     663     validation_freq=validation_freq,
#     664     steps_name='steps_per_epoch')
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_arrays_v1.py:384, in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     381 callbacks._call_batch_hook(mode, 'begin', batch_index, batch_logs)
#     383 # Get outputs.
# --> 384 batch_outs = f(ins_batch)
#     385 if not isinstance(batch_outs, list):
#     386   batch_outs = [batch_outs]
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:3956, in GraphExecutionFunction.__call__(self, inputs)
#    3950 if (self._callable_fn is None or feed_arrays != self._feed_arrays or
#    3951     symbol_vals != self._symbol_vals or
#    3952     feed_symbols != self._feed_symbols or self.fetches != self._fetches or
#    3953     session != self._session):
#    3954   self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
# -> 3956 fetched = self._callable_fn(*array_vals,
#    3957                             run_metadata=self.run_metadata)
#    3958 self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3959 output_structure = nest.pack_sequence_as(
#    3960     self._outputs_structure,
#    3961     fetched[:len(self.outputs)],
#    3962     expand_composites=True)
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/client/session.py:1480, in BaseSession._Callable.__call__(self, *args, **kwargs)
#    1478 try:
#    1479   run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1480   ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1481                                          self._handle, args,
#    1482                                          run_metadata_ptr)
#    1483   if run_metadata:
#    1484     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
dqlagent.test(3)
# Out:
# total reward=2507 | accuracy=0.514
# total reward=2507 | accuracy=0.514
# total reward=2507 | accuracy=0.514

# %%
from simulation import Simulation

# %%
random.seed(500)

# %%
simulation = Simulation('SYMBOL', 'r', 4, '2025-1-1', '2028-1-1',
                2 * 252, min_accuracy=0.5, x0=1, kappa=1,
                theta=0.75, sigma=0.1, new=True, normalize=True)
# simulation = synth
# Out:
# ====> :                                  SYMBOL
# 2025-01-01 00:00:00.000000000  1.000000
# 2025-01-03 04:14:47.475149105  1.004037
# 2025-01-05 08:29:34.950298210  0.984428
# 2025-01-07 12:44:22.425447316  0.977889
# 2025-01-09 16:59:09.900596421  0.973794
# ...                                 ...
# 2027-12-23 07:00:50.099403584  0.799486
# 2027-12-25 11:15:37.574552688  0.800624
# 2027-12-27 15:30:25.049701792  0.789414
# 2027-12-29 19:45:12.524850896  0.785096
# 2028-01-01 00:00:00.000000000  0.790836
#
# [504 rows x 1 columns]
# type : <class 'pandas.core.frame.DataFrame'>

# %%
simulation = Simulation('SYMBOL', 'r', 4, '2023-1-1', '2023-2-1',
                2 * 252, min_accuracy=0.7, x0=1, kappa=1,
                theta=0.75, sigma=0.1, new=True, normalize=True)
# Out:
# =====>                                  SYMBOL
# 2023-01-01 00:00:00.000000000  0.504878
# 2023-01-01 01:28:55.458167330  0.504550
# 2023-01-01 02:57:50.916334661  0.500479
# 2023-01-01 04:26:46.374501992  0.507781
# 2023-01-01 05:55:41.832669322  0.501008
# ...                                 ...
# 2023-01-31 18:04:18.167330677  0.516601
# 2023-01-31 19:33:13.625498008  0.500622
# 2023-01-31 21:02:09.083665339  0.500315
# 2023-01-31 22:31:04.541832669  0.513745
# 2023-02-01 00:00:00.000000000  0.509971
#
# [503 rows x 1 columns]

# %%
for _ in range(1):
    simulation.reset()
    simulation.data[simulation.symbol].plot(title=simulation.symbol,
                                           lw=0.10, c='b');

# simulation.plot_distributions()
# Out:
# =====>                                  SYMBOL
# 2023-01-01 00:00:00.000000000  0.500303
# 2023-01-01 01:28:55.458167330  0.500038
# 2023-01-01 02:57:50.916334661  0.500359
# 2023-01-01 04:26:46.374501992  0.500044
# 2023-01-01 05:55:41.832669322  0.500351
# ...                                 ...
# 2023-01-31 18:04:18.167330677  0.504523
# 2023-01-31 19:33:13.625498008  0.500131
# 2023-01-31 21:02:09.083665339  0.501581
# 2023-01-31 22:31:04.541832669  0.501256
# 2023-02-01 00:00:00.000000000  0.500495
#
# [503 rows x 1 columns]

# %%
simulation.data
# Out:
#                                  SYMBOL         r  d
# 2025-01-03 04:21:02.151394422  0.000392  0.021870  1
# 2025-01-05 08:42:04.302788844  0.000389 -0.007128  0
# 2025-01-07 13:03:06.454183267  0.000383 -0.015336  0
# 2025-01-09 17:24:08.605577689  0.000390  0.018215  1
# 2025-01-11 21:45:10.756972111  0.000386 -0.012259  0
# ...                                 ...       ... ..
# 2027-12-23 06:35:51.394422304  0.000384  0.000114  1
# 2027-12-25 10:56:53.545816736  0.000384  0.000300  1
# 2027-12-27 15:17:55.697211152  0.000383 -0.000724  0
# 2027-12-29 19:38:57.848605584  0.000391  0.020837  1
# 2028-01-01 00:00:00.000000000  0.000387 -0.011433  0
#
# [502 rows x 3 columns]

# %%
simulation.data
# Out:
#                                  SYMBOL         r  d
# 2025-01-03 04:14:47.475149105  0.993453 -0.006569  0
# 2025-01-05 08:29:34.950298210  0.990928 -0.002544  0
# 2025-01-07 12:44:22.425447316  0.987547 -0.003418  0
# 2025-01-09 16:59:09.900596421  0.979565 -0.008115  0
# 2025-01-11 21:13:57.375745526  0.973214 -0.006505  0
# ...                                 ...       ... ..
# 2027-12-23 07:00:50.099403584  0.840882  0.000305  1
# 2027-12-25 11:15:37.574552688  0.836046 -0.005768  0
# 2027-12-27 15:30:25.049701792  0.841488  0.006488  1
# 2027-12-29 19:45:12.524850896  0.839506 -0.002358  0
# 2028-01-01 00:00:00.000000000  0.837968 -0.001833  0
#
# [503 rows x 3 columns]

# %%
random.seed(100)
tf.random.set_seed(100)

# %%
agent = DQLAgent(simulation.symbol, simulation.feature,
                 simulation.n_features, simulation)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:211, in make_shape(v, arg_name)
#     210 try:
# --> 211   shape = tensor_shape.as_shape(v)
#     212 except TypeError as e:
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/framework/tensor_shape.py:1235, in as_shape(shape)
#    1234 else:
# -> 1235   return TensorShape(shape)
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/framework/tensor_shape.py:758, in TensorShape.__init__(self, dims)
#     757 if isinstance(dims, (tuple, list)):  # Most common case.
# --> 758   self._dims = [Dimension(d) for d in dims]
#     759 elif dims is None:
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/framework/tensor_shape.py:758, in <listcomp>(.0)
#     757 if isinstance(dims, (tuple, list)):  # Most common case.
# --> 758   self._dims = [Dimension(d) for d in dims]
#     759 elif dims is None:
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/framework/tensor_shape.py:203, in Dimension.__init__(self, value)
#     202 except AttributeError:
# --> 203   six.raise_from(
#     204       TypeError("Dimension value must be integer or None or have "
#     205                 "an __index__ method, got value '{0!r}' with type '{1!r}'"
#     206                 .format(value, type(value))), None)
#     207 if self._value < 0:
#
# File <string>:3, in raise_from(value, from_value)
#
# TypeError: Dimension value must be integer or None or have an __index__ method, got value ''SYMBOL'' with type '<class 'str'>'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 agent = DQLAgent(simulation.symbol, simulation.feature,
#       2                  simulation.n_features, simulation)
#
# File ~/RL/RL_platform/RL_for_finance/dqlagent.py:42, in DQLAgent.__init__(self, n_features, env, hu, lr)
#      40 self.env = env
#      41 self.episodes = 0
# ---> 42 self._create_model(hu, lr)
#
# File ~/RL/RL_platform/RL_for_finance/dqlagent.py:46, in DQLAgent._create_model(self, hu, lr)
#      44 def _create_model(self, hu, lr):
#      45     self.model = Sequential()
# ---> 46     self.model.add(Dense(hu, activation='relu',
#      47                          input_dim=self.n_features))
#      48     self.model.add(Dense(hu, activation='relu'))
#      49     self.model.add(Dense(2, activation='linear'))
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py:517, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     515 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516 try:
# --> 517   result = method(self, *args, **kwargs)
#     518 finally:
#     519   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:203, in Sequential.add(self, layer)
#     200 batch_shape, dtype = training_utils.get_input_shape_and_dtype(layer)
#     201 if batch_shape:
#     202   # Instantiate an input layer.
# --> 203   x = input_layer.Input(
#     204       batch_shape=batch_shape, dtype=dtype, name=layer.name + '_input')
#     205   # This will build the current layer
#     206   # and create the node connecting the current layer
#     207   # to the input layer we just created.
#     208   layer(x)
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_layer.py:309, in Input(shape, batch_size, name, dtype, sparse, tensor, ragged, **kwargs)
#     306 else:
#     307   input_layer_config.update(
#     308       {'batch_size': batch_size, 'input_shape': shape})
# --> 309 input_layer = InputLayer(**input_layer_config)
#     311 # Return tensor including `_keras_history`.
#     312 # Note that in this case train_output and test_output are the same pointer.
#     313 outputs = input_layer._inbound_nodes[0].outputs
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_layer.py:155, in InputLayer.__init__(self, input_shape, batch_size, dtype, input_tensor, sparse, name, ragged, **kwargs)
#     153 graph = backend.get_graph()
#     154 with graph.as_default():
# --> 155   input_tensor = backend.placeholder(
#     156       shape=batch_input_shape,
#     157       dtype=dtype,
#     158       name=self.name,
#     159       sparse=sparse,
#     160       ragged=ragged)
#     162 self.is_placeholder = True
#     163 self._batch_input_shape = batch_input_shape
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:1265, in placeholder(shape, ndim, dtype, sparse, name, ragged)
#    1262       x = nest.map_structure(tensor_spec_to_placeholder, type_spec,
#    1263                              expand_composites=True)
#    1264     else:
# -> 1265       x = array_ops.placeholder(dtype, shape=shape, name=name)
#    1267 if context.executing_eagerly():
#    1268   # Add keras_history connectivity information to the placeholder
#    1269   # when the placeholder is built in a top-level eager context
#    1270   # (intended to be used with keras.backend.function)
#    1271   from tensorflow.python.keras.engine import input_layer  # pylint: disable=g-import-not-at-top
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:3179, in placeholder(dtype, shape, name)
#    3175 if context.executing_eagerly():
#    3176   raise RuntimeError("tf.placeholder() is not compatible with "
#    3177                      "eager execution.")
# -> 3179 return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:6724, in placeholder(dtype, shape, name)
#    6722 if shape is None:
#    6723   shape = None
# -> 6724 shape = _execute.make_shape(shape, "shape")
#    6725 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    6726       "Placeholder", dtype=dtype, shape=shape, name=name)
#    6727 _result = _outputs[:]
#
# File ~/miniconda3/envs/keras_env/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:213, in make_shape(v, arg_name)
#     211   shape = tensor_shape.as_shape(v)
#     212 except TypeError as e:
# --> 213   raise TypeError("Error converting %s to a TensorShape: %s." % (arg_name, e))
#     214 except ValueError as e:
#     215   raise ValueError("Error converting %s to a TensorShape: %s." % (arg_name,
#     216                                                                   e))
#
# TypeError: Error converting shape to a TensorShape: Dimension value must be integer or None or have an __index__ method, got value ''SYMBOL'' with type '<class 'str'>'.

# %%
# %time agent.learn(250)
# Out:
# episode= 250 | treward=276.000 | max=277.000
# CPU times: user 4min 28s, sys: 9min 59s, total: 14min 27s
# Wall time: 1min 18s

# %%
agent.test(10)
# Out:
# total reward= 499 | accuracy=0.469
# total reward= 499 | accuracy=0.537
# total reward= 499 | accuracy=0.525
# total reward= 499 | accuracy=0.527
# total reward= 499 | accuracy=0.511
# total reward= 499 | accuracy=0.481
# total reward= 499 | accuracy=0.503
# total reward= 499 | accuracy=0.519
# total reward= 499 | accuracy=0.489
# total reward= 499 | accuracy=0.515

# %%
class ActionSpace:
    def sample(self):
        return random.randint(0, 1)

# %%
class Trading:
    def __init__(self, symbol, features, window, lags,
                 start, end, periods,
                 x0=100, kappa=1, theta=100, sigma=0.2,
                 leverage=1, min_accuracy=0.5, min_performance=0.85,
                 mu=None, std=None,
                 new=True, normalize=True):
        self.symbol = symbol
        self.features = features
        self.n_features = len(features)
        self.window = window
        self.lags = lags
        self.start = start
        self.end = end
        self.periods = periods
        self.x0 = x0
        self.kappa = kappa
        self.theta = theta
        self.sigma = sigma
        self.leverage = leverage
        self.min_accuracy = min_accuracy
        self.min_performance = min_performance
        self.start = start
        self.end = end
        self.mu = mu
        self.std = std
        self.new = new
        self.normalize = normalize
        self.action_space = ActionSpace()
        self._simulate_data()
        self._prepare_data()

# %%
class Trading(Trading):
    def _simulate_data(self):
        index = pd.date_range(start=self.start,
                    end=self.end, periods=self.periods)
        s = [self.x0]
        dt = (index[-1] - index[0]).days / 365 / self.periods
        for t in range(1, len(index)):
            s_ = (s[t - 1] + self.kappa * (self.theta - s[t - 1]) * dt +
              s[t - 1] * self.sigma * math.sqrt(dt) *
                random.gauss(0, 1))
            s.append(s_)
        self.data = pd.DataFrame(s, columns=[self.symbol], index=index)

# %%
class Trading(Trading):
    def _prepare_data(self):
        self.data['r'] = np.log(self.data / self.data.shift(1))
        self.data.dropna(inplace=True)
        # additional features
        if self.window > 0:
            self.data['SMA'] = self.data[
                self.symbol].rolling(self.window).mean()
            self.data['DEL'] = self.data[
                self.symbol] - self.data['SMA']
            self.data['MIN'] = self.data[
                self.symbol].rolling(self.window).min()
            self.data['MAX'] = self.data[
                self.symbol].rolling(self.window).max()
            self.data['MOM'] = self.data['r'].rolling(
                self.window).mean()
            # add more features here
            self.data.dropna(inplace=True)
        if self.normalize:
            if self.mu is None or self.std is None:
                self.mu = self.data.mean()
                self.std = self.data.std()
            self.data_ = (self.data - self.mu) / self.std
        else:
            self.data_ = self.data.copy()
        self.data['d'] = np.where(self.data['r'] > 0, 1, 0)
        self.data['d'] = self.data['d'].astype(int)

# %%
class Trading(Trading):
    def _get_state(self):
        return self.data_[self.features].iloc[self.bar -
                                self.lags:self.bar]
    def seed(self, seed):
        random.seed(seed)
        np.random.seed(seed)
        tf.random.set_random_seed(seed)
    def reset(self):
        if self.new:
            self._simulate_data()
            self._prepare_data()
        self.treward = 0
        self.accuracy = 0
        self.actions = list()
        self.returns = list()
        self.performance = 1
        self.bar = self.lags
        state = self._get_state()
        return state.values, {}

# %%
class Trading(Trading):
    def step(self, action):
        correct = action == self.data['d'].iloc[self.bar]
        ret = self.data['r'].iloc[self.bar] * self.leverage
        reward_ = 1 if correct else 0
        pl = abs(ret) if correct else -abs(ret)
        reward = reward_
        # alternative options:
        # reward = pl  # only the P&L in log returns
        # reward = reward_ + 10 * pl  # the reward + the scaled P&L
        self.treward += reward
        self.bar += 1
        self.accuracy = self.treward / (self.bar - self.lags) 
        self.performance *= math.exp(pl)
        if self.bar >= len(self.data):
            done = True
        elif reward_ == 1:
            done = False
        elif (self.accuracy < self.min_accuracy and
              self.bar > self.lags + 15):
            done = True
        elif (self.performance < self.min_performance and
              self.bar > self.lags + 15):
            done = True
        else:
            done = False
        state = self._get_state()
        return state.values, reward, done, False, {}

# %%
symbol = 'XAUUSD'

# %%
trading = Trading(symbol, [symbol, 'r', 'DEL'], window=10, lags=5,
            start='2024-1-1', end='2026-1-1', periods=504,
            x0=100, kappa=2, theta=300, sigma=0.1, normalize=False)

# %%
random.seed(750)

# %%
trading.reset()
# Out:
# (array([[115.90591443,   0.01926915,   6.89239862],
#         [117.17850569,   0.01091968,   6.5901155 ],
#         [118.79489427,   0.01369997,   6.65876779],
#         [120.63380354,   0.01536111,   6.92684742],
#         [121.81132396,   0.00971378,   6.65768164]]),
#  {})

# %%
trading.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 494 entries, 2024-01-15 12:47:14.194831014 to 2026-01-01 00:00:00
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   XAUUSD  494 non-null    float64
#  1   r       494 non-null    float64
#  2   SMA     494 non-null    float64
#  3   DEL     494 non-null    float64
#  4   MIN     494 non-null    float64
#  5   MAX     494 non-null    float64
#  6   MOM     494 non-null    float64
#  7   d       494 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 34.7 KB

# %%
trading.data.iloc[-500:-300][
    [trading.symbol, 'SMA', 'MIN', 'MAX']].plot(
        style=['b-', 'r--', 'g:', 'g:'], lw=1.0);

# %%
class TradingAgent(DQLAgent):
    def _create_model(self, hu, lr):
        self.model = Sequential()
        self.model.add(Dense(hu, input_dim=
            self.env.lags * self.env.n_features,
                        activation='relu'))
        self.model.add(Flatten())
        self.model.add(Dense(hu, activation='relu'))
        self.model.add(Dense(2, activation='linear'))
        self.model.compile(loss='mse',
            optimizer=opt(learning_rate=lr))

# %%
random.seed(100)
tf.random.set_seed(100)

# %%
trading = Trading(symbol, ['r', 'DEL', 'MOM'], window=10, lags=8,
            start='2024-1-1', end='2026-1-1', periods=2 * 252,
            x0=100, kappa=2, theta=50, sigma=0.1,
            leverage=1, min_accuracy=0.5, min_performance=0.85,
            new=True, normalize=True)

# %%
tradingagent = TradingAgent(trading.symbol, trading.features,
                 trading.n_features, trading, hu=24, lr=0.0001)

# %%
# %%time
tradingagent.test(100, min_accuracy=0.0,
           min_performance=0.0,
           verbose=True, full=False)
# Out:
# total reward= 486 | accuracy=0.580 | performance=1.687
# CPU times: user 11min 36s, sys: 26min 26s, total: 38min 2s
# Wall time: 3min 37s

# %%
random_performances = tradingagent.performances

# %%
sum(random_performances) / len(random_performances)
# Out:
# 1.7750373833506712

# %%
plt.hist(random_performances, bins=50, color='b')
plt.xlabel('gross performance')
plt.ylabel('frequency');

# %%
# %time tradingagent.learn(500)
# Out:
# episode= 500 | treward=265.000 | max=292.000
# CPU times: user 28min 46s, sys: 1h 5min 25s, total: 1h 34min 11s
# Wall time: 9min 2s

# %%
# %%time
tradingagent.test(50, min_accuracy=0.0,
           min_performance=0.0,
           verbose=True, full=False)
# Out:
# total reward= 486 | accuracy=0.537 | performance=1.319
# CPU times: user 6min 23s, sys: 14min 35s, total: 20min 59s
# Wall time: 2min 2s

# %%
sum(tradingagent.performances) / len(tradingagent.performances)
# Out:
# 1.5708525087589242

# %%
plt.hist(random_performances, bins=30,
         color='b', label='random (left)')
plt.hist(tradingagent.performances, bins=30,
         color='r', label='trained(right)')
plt.xlabel('gross performance')
plt.ylabel('frequency')
plt.legend();

# %% [markdown]
# <img src="https://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="https://tpq.io" target="_blank">https://tpq.io</a> | <a href="https://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:team@tpq.io">team@tpq.io</a>
